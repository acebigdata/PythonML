# %%
import pandas as pd

# %%
pwd
# Out:
# 'C:\\PythonML'

# %%
data_1 = pd.read_csv("data.csv")
data_1
# Out:
#     index    area  bathrooms     price    sq_price
# 0       0  2104.0        3.0  399900.0  190.066540
# 1       1  1600.0        3.0  329900.0  206.187500
# 2       2  2400.0        3.0  369000.0  153.750000
# 3       3  1416.0        2.0  232000.0  163.841808
# 4       4  3000.0        4.0  539900.0  179.966667
# 5       5  1985.0        4.0  299900.0  151.083123
# 6       6  1534.0        3.0  314900.0  205.280313
# 7       7  1427.0        3.0  198999.0  139.452698
# 8       8  1380.0        3.0  212000.0  153.623188
# 9       9  1494.0        3.0  242500.0  162.315930
# 10     10  1940.0        4.0  239999.0  123.710825
# 11     11  2000.0        3.0  347000.0  173.500000
# 12     12  1890.0        3.0  329999.0  174.602646
# 13     13  4478.0        5.0  699900.0  156.297454
# 14     14  1268.0        3.0  259900.0  204.968454
# 15     15  2300.0        4.0  449900.0  195.608696
# 16     16  1320.0        2.0  299900.0  227.196970
# ...

# %%
data_1.drop("index", axis = 1, inplace = True)

# %%
data_1.to_csv("data_1.csv")

# %%
pwd
# Out:
# 'C:\\PythonML'

# %%
dir
# Out:
# <function dir>

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 36F2-291D
#
#  Directory of C:\PythonML
#
# 01/25/2017  06:24 PM    <DIR>          .
# 01/25/2017  06:24 PM    <DIR>          ..
# 01/25/2017  05:56 PM    <DIR>          .ipynb_checkpoints
# 10/03/2016  07:45 PM    <DIR>          __MACOSX
# 01/25/2017  03:12 PM        29,386,132 AVA_Model_01172017_v9.xlsx
# 01/25/2017  10:41 AM               622 Conditional Selection.ipynb
# 01/25/2017  01:19 PM             1,778 data.csv
# 01/25/2017  06:26 PM             1,825 data_1.csv
# 01/25/2017  05:48 PM            22,354 DF_Operation.ipynb
# 01/25/2017  04:06 PM            11,828 DF_P3.ipynb
# 01/25/2017  06:24 PM            43,183 Input_Output.ipynb
# 01/24/2017  02:23 PM             6,493 L1 Crash Ex.ipynb
# 01/24/2017  08:51 AM             9,945 L1_part2.ipynb
# 01/24/2017  05:13 PM            17,373 Numpy Array.ipynb
# 01/24/2017  06:42 PM            10,405 Numpy_Ex.ipynb
# ...

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 36F2-291D
#
#  Directory of C:\PythonML
#
# 01/25/2017  06:24 PM    <DIR>          .
# 01/25/2017  06:24 PM    <DIR>          ..
# 01/25/2017  05:56 PM    <DIR>          .ipynb_checkpoints
# 10/03/2016  07:45 PM    <DIR>          __MACOSX
# 01/25/2017  03:12 PM        29,386,132 AVA_Model_01172017_v9.xlsx
# 01/25/2017  10:41 AM               622 Conditional Selection.ipynb
# 01/25/2017  01:19 PM             1,778 data.csv
# 01/25/2017  06:26 PM             1,825 data_1.csv
# 01/25/2017  05:48 PM            22,354 DF_Operation.ipynb
# 01/25/2017  04:06 PM            11,828 DF_P3.ipynb
# 01/25/2017  06:24 PM            43,183 Input_Output.ipynb
# 01/24/2017  02:23 PM             6,493 L1 Crash Ex.ipynb
# 01/24/2017  08:51 AM             9,945 L1_part2.ipynb
# 01/24/2017  05:13 PM            17,373 Numpy Array.ipynb
# 01/24/2017  06:42 PM            10,405 Numpy_Ex.ipynb
# ...

# %%
data_xl = pd.read_excel("AVA_Model_01172017_v9.xlsx", sheetname = "Total Revenue", header = 1)

# %%
data_xl.head()
# Out:
#    IQ_TOTAL_REV           Wal-Mart Stores, Inc. (NYSE:WMT)       NYSE:WMT  \
# 0           NaN        Toyota Motor Corporation (TSE:7203)       TSE:7203
# 1           NaN  Volkswagen Aktiengesellschaft (XTRA:VOW3)      XTRA:VOW3
# 2           NaN        Royal Dutch Shell plc (ENXTAM:RDSA)    ENXTAM:RDSA
# 3           NaN                 Apple Inc. (NasdaqGS:AAPL)  NasdaqGS:AAPL
# 4           NaN       Berkshire Hathaway Inc. (NYSE:BRK.A)     NYSE:BRK.A
#
#    Unnamed: 3  United States            NA  \
# 0         NaN          Japan  Asia-Pacific
# 1         NaN        Germany        Europe
# 2         NaN    Netherlands        Europe
# 3         NaN  United States           NaN
# 4         NaN  United States           NaN
#
#                  Hypermarkets and Super Centers                    Services  \
# 0                      Automobile Manufacturers       Auto & Transportation
# 1                      Automobile Manufacturers       Auto & Transportation
# ...

# %%
failed_bank = pd.read_html("https://www.fdic.gov/bank/individual/failed/banklist.html")

# %%
failed_bank[0].head()
# Out:
#                       Bank Name             City  ST   CERT  \
# 0        Harvest Community Bank       Pennsville  NJ  34951
# 1                   Allied Bank         Mulberry  AR     91
# 2  The Woodbury Banking Company         Woodbury  GA  11297
# 3        First CornerStone Bank  King of Prussia  PA  35312
# 4            Trust Company Bank          Memphis  TN   9956
#
#                  Acquiring Institution        Closing Date       Updated Date
# 0  First-Citizens Bank & Trust Company    January 13, 2017   January 19, 2017
# 1                         Today's Bank  September 23, 2016  November 17, 2016
# 2                          United Bank     August 19, 2016  November 17, 2016
# 3  First-Citizens Bank & Trust Company         May 6, 2016  September 6, 2016
# 4           The Bank of Fayette County      April 29, 2016  September 6, 2016

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///:memory:')

# %%
data_xl.to_sql("total revenue", engine)

# %%
sql_rev = pd.read_sql('total revenue',con=engine)

# %%
sql_rev
# Out:
#       index  IQ_TOTAL_REV                   Wal-Mart Stores, Inc. (NYSE:WMT)  \
# 0         0           NaN                Toyota Motor Corporation (TSE:7203)
# 1         1           NaN          Volkswagen Aktiengesellschaft (XTRA:VOW3)
# 2         2           NaN                Royal Dutch Shell plc (ENXTAM:RDSA)
# 3         3           NaN                         Apple Inc. (NasdaqGS:AAPL)
# 4         4           NaN               Berkshire Hathaway Inc. (NYSE:BRK.A)
# 5         5           NaN                 Exxon Mobil Corporation (NYSE:XOM)
# 6         6           NaN                    McKesson Corporation (NYSE:MCK)
# 7         7           NaN         UnitedHealth Group Incorporated (NYSE:UNH)
# 8         8           NaN        Samsung Electronics Co. Ltd. (KOSE:A005930)
# 9         9           NaN                                BP p.l.c. (LSE:BP.)
# 10       10           NaN                  CVS Health Corporation (NYSE:CVS)
# ...
